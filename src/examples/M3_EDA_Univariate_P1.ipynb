# %% [markdown]
# ## Univariate Data Analysis - Numerical Variable

# %%
# STEP 1: Clone GitHub Repo
# %cd /content
# !git clone https://github.com/GourabNath/Project-Pulse.git
# %cd Project-Pulse
# Out:
# /content
# Cloning into 'Project-Pulse'...
# remote: Enumerating objects: 485, done.
# remote: Counting objects: 100% (240/240), done.
# remote: Compressing objects: 100% (207/207), done.
# remote: Total 485 (delta 116), reused 70 (delta 32), pack-reused 245 (from 1)
# Receiving objects: 100% (485/485), 92.65 KiB | 1.29 MiB/s, done.
# Resolving deltas: 100% (221/221), done.
# /content/Project-Pulse

# %% [markdown]
# ## EDA Playground

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
json_file_path = "/content/drive/MyDrive/0_AI_Projects/00_Project_Pulse/Attrition/attrition_data.json"
attrition_file_path = "/content/drive/MyDrive/0_AI_Projects/00_Project_Pulse/Attrition/Employee_Attrition.csv"

# %%
from src.controllers.eda_1 import univariate_eda_num
univariate_eda_num(attrition_file_path, json_file_path)
# Out:
# ## Summary Statistics
# --------------------------------------------------------------------------------
# **Variable:** Age
# **Variable Type:** Continuous
# Since the variable is continuous let us start by printing the **descriptive statistics** of the variable.
# --------------------------------------------------------------------------------
# **Use code:**
# `df['Age'].describe()`
# count    1470.000000
# mean       36.923810
# std         9.135373
# min        18.000000
# 25%        30.000000
# 50%        36.000000
# 75%        43.000000
# max        60.000000
# Name: Age, dtype: float64
# --------------------------------------------------------------------------------
# Press ENTER to continue
# *Now let's discuss how we can interpret and report these results...*
# **Count = 1,470**.
# There are 1,470 non-missing rows present in the dataset. In other words, we have complete details about 1,470 employees in our dataset.
# ...
