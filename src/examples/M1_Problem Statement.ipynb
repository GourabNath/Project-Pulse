# %% [markdown]
# # Define Problem Statement

# %%
# STEP 1: Enter your OpenAI key over here
import os
import getpass
os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter key: ")
# Out:
# Enter key: ··········

# %%
# STEP 2: Clone GitHub Repo
# %cd /content
# !git clone https://github.com/GourabNath/Project-Pulse.git
# %cd Project-Pulse
# Out:
# /content
# Cloning into 'Project-Pulse'...
# remote: Enumerating objects: 366, done.
# remote: Counting objects: 100% (121/121), done.
# remote: Compressing objects: 100% (115/115), done.
# remote: Total 366 (delta 51), reused 17 (delta 6), pack-reused 245 (from 1)
# Receiving objects: 100% (366/366), 71.13 KiB | 946.00 KiB/s, done.
# Resolving deltas: 100% (156/156), done.
# /content/Project-Pulse

# %%
# STEP 3: Have fun with designing the problem statement with our AI-assistant
from src.controllers.problem_controller import define_problem_statement
problem_description =       #NOTE FOR DEVELOPER: THIS SHOULD COME FROM A **REMOTE** JSON FILE
problem_statement = define_problem_statement(problem_description)
# Out:
# In a mid-sized organization, the human resources team has noticed an increasing concern: the company faces an unexpected employee attrition rate of around 18% each year. While some turnover is anticipated in any dynamic business environment, this level of unexpected departures is beginning to impact operational stability and team cohesion. Leadership is eager to understand the underlying patterns driving this attrition and whether current retention strategies are effective. Yet, despite ongoing efforts, the reasons b

# %%
# STEP 5: Save the discussion

# Mount directory
from google.colab import drive
drive.mount('/content/drive')

# Enter your working directory
project_folder_path = "/content/drive/MyDrive/0. AI Projects/00. Project Pulse/Main"

# Save results
import json
import os

file_name = "problem_statement.json"
file_path = os.path.join(project_folder_path, file_name)

with open(file_path, 'w') as f:
    json.dump(problem_statement, f, indent=4)

print(f"Problem statement saved to {file_path}")
