# %% [markdown]
# ## Variable Description and Variable Type Identification

# %%
# STEP 1: Enter your OpenAI key over here
import os
import getpass
os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter key: ")

# %%
# STEP 2: Clone GitHub Repo
# %cd /content
# !git clone https://github.com/GourabNath/Project-Pulse.git
# %cd Project-Pulse

# %%
# STEP 3: Load the variable description data
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
variable_df = pd.read_csv("Attrition/variable_description_attrition.csv", encoding='latin1')

# %%
# STEP 4: Have fun with understanding variables and identifying variable types
row_description = row_description = "each row of this data represents an employee."

#from src.engines.utils.typewriter import stream_markdown
from src.engines.utils.print_multiple_lines import print_multiple_lines
from src.controllers.variable_identification_controller import variable_identification

variable_identification(variable_df, row_description)
